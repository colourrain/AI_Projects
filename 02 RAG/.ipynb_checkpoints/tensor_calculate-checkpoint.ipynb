# %%
# enbedding test
from transformers import AutoTokenizer, AutoModel
from sentence_transformers.util import cos_sim
import torch.nn.functional as F

# %%
input_texts=[
    "中国的首都在哪里？",
    "你喜欢去哪里旅游？",
    "上海",
    "今天中午吃什么"
]

# %%
model_path = '../model/Qwen2.5-0.5B-Instruct/'
tokenlizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModel.from_pretrained(model_path,device_map="cpu")

# %%
batch_tokens = tokenlizer(input_texts,
                         max_length=30,
                         padding=True,
                         truncation=True,
                         return_tensors="pt")

# %%
batch_tokens.input_ids[1]
# Out:
# tensor([113540, 115414,  99790,  11319, 151643])

# %%
output = model(** batch_tokens)

# %%
output
# Out:
# BaseModelOutputWithPast(last_hidden_state=tensor([[[ -4.4584,  -1.5763,   4.2350,  ...,   1.2038,  -4.1824,   4.3375],
#          [ -2.1473,   5.0405,  -0.5864,  ...,   1.2575,  -2.5258,  11.6709],
#          [ -1.3329,  -3.4988,   2.3926,  ...,  -8.5137,   3.0898,  -8.5593],
#          [ -3.0730,  -1.2178,   1.3683,  ...,  -9.3675,  -2.3741, -12.1517],
#          [ -0.9667,  -1.7155,   2.2610,  ...,  -8.9641,  -1.8127,  -7.4504]],
#
#         [[ -2.2944,   0.3050,   2.7537,  ...,   3.2119,  -0.5060,   2.6512],
#          [  0.7636,  11.9393,  -1.0057,  ...,  -0.4191,  -8.4093,  -7.5825],
#          [  0.2322,   9.8162,  -1.0752,  ...,  -3.3775,  -3.2053,  -8.8617],
#          [  0.8157,   6.8189,   2.2637,  ...,  -2.4609,   0.7596, -15.1734],
#          [ -1.7422,   2.8334,   2.3439,  ...,   1.3161,   1.3841, -11.4268]],
#
#         [[ -0.4301,   3.8735,   6.4584,  ...,   3.2485,  -0.3578,  -2.9828],
#          [  0.5147,  -0.7468,  -0.9919,  ...,   3.7203,  -4.7462,  -3.4111],
#          [  0.5147,  -0.7468,  -0.9919,  ...,   3.7203,  -4.7462,  -3.4111],
#          [  0.5148,  -0.7468,  -0.9919,  ...,   3.7203,  -4.7462,  -3.4111],
#          [  0.5147,  -0.7468,  -0.9919,  ...,   3.7203,  -4.7462,  -3.4111]],
#
#         [[  1.9025,   6.3438,   6.0075,  ...,   4.3497,  -1.6912,  -3.1847],
#          [ -0.2552,  -4.8799,  -1.8117,  ...,  -1.2402,  -0.7855,  -2.5082],
#          [ -2.5298,  -1.2361,  -4.3012,  ...,  -3.8994,   0.7112,  -0.3814],
#          [ -0.5938,  -0.8700,   5.3044,  ...,   3.5181,   1.8144,  -3.0772],
#          [ -2.1514,   2.6708,   4.7430,  ...,  -0.1326,   0.8796,  -7.0553]]],
#        grad_fn=<MulBackward0>), past_key_values=DynamicCache(layers=[DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer]), hidden_states=None, attentions=None)

# %%
output.last_hidden_state.shape
# Out:
# torch.Size([4, 5, 896])

# %%
embeddings = output.last_hidden_state[:,0]

# %%
embeddings.shape
# Out:
# torch.Size([4, 896])

# %%
embeddings= F.normalize(embeddings, p=2, dim=1)

# %%
for i in range(1,4):
    print(input_texts[0], input_texts[i], cos_sim(embeddings[0], embeddings[i]))
# Out:
# 中国的首都在哪里？ 你喜欢去哪里旅游？ tensor([[0.7625]], grad_fn=<MmBackward0>)
# 中国的首都在哪里？ 上海 tensor([[0.8954]], grad_fn=<MmBackward0>)
# 中国的首都在哪里？ 今天中午吃什么 tensor([[0.7764]], grad_fn=<MmBackward0>)

# %%
# 利用sentence_transformer
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim
input_texts=[
    "中国的首都在哪里？",
    "你喜欢去哪里旅游？",
    "上海",
    "今天中午吃什么"
]

# %%
model2 = SentenceTransformer(model_path)
# Out:
# No sentence-transformers model found with name ../model/Qwen2.5-0.5B-Instruct/. Creating a new one with mean pooling.
