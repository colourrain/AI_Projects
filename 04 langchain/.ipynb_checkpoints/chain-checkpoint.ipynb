# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_community.llms import Ollama

# %%
llm = Ollama(model="qwen2.5:3b", temperature=0.1)

# %%
from langchain.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template(
    "what is the best name to describe a company that makes {product}?\n\n"
    "The name should be short, catchy, and easy to remember.\n\n")

# %%
chain = prompt | llm

# %%
product = "a new kind of electric car"
chain.invoke(input=product)
# Out:
# 'How about "EvoDrive"? It\'s short, has a futuristic feel with its use of "Drive," and can be easily remembered.'

# %%
from langchain.chains import SimpleSequentialChain
# promot template one
prompt1 = ChatPromptTemplate.from_template(
    "what is the best name to describe a company that makes {product}?\n\n"
    "The name should be short, catchy, and easy to remember. Just ouput the name only.\n\n")
chain1 = prompt1 | llm

# %%
# promot template one
prompt2 = ChatPromptTemplate.from_template(
    "write a 20 words description for the following company {company_name}.")
chain2 = prompt2 | llm

# %%
overall_simple_chain = SimpleSequentialChain(chains=[chain1, chain2], verbose=True)
product = "a new kind of electric car"
overall_simple_chain.invoke(input=product)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 overall_simple_chain = SimpleSequentialChain(chains=[chain1, chain2], verbose=True)
#       2 product = "a new kind of electric car"
#       3 overall_simple_chain.invoke(input=product)
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain\chains\base.py:233, in Chain.raise_callback_manager_deprecation(cls, values)
#     229 @model_validator(mode="before")
#     230 @classmethod
#     231 def raise_callback_manager_deprecation(cls, values: dict) -> Any:
#     232     """Raise deprecation warning if callback_manager is used."""
# --> 233     if values.get("callback_manager") is not None:
#     234         if values.get("callbacks") is not None:
#     235             raise ValueError(
#     236                 "Cannot specify both callback_manager and callbacks. "
#     237                 "callback_manager is deprecated, callbacks is the preferred "
#     238                 "parameter to pass in."
#     239             )
#
# File d:\anaconda3\envs\bo\Lib\site-packages\pydantic\main.py:989, in BaseModel.__getattr__(self, item)
#     986     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     987 else:
#     988     # this is the current error
# --> 989     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'RunnableSequence' object has no attribute 'get'
