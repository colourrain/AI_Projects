# %%
# 连接到LLM模型
# 连接到LLM模型
from langchain_community.llms import Ollama
llm = Ollama(model="qwen2.5:3b")

# %%
llm.invoke("The first man on the moon was ...")
# Out:
# 'The first person to walk on the Moon was Neil Armstrong, who made his historic step in 1969 as part of the Apollo 11 mission.'

# %%
customer_email = """
Arrr, I be fuming that me blender lid \
flew off and splattered me kitchen walls \
with smoothie. I be needin' a new lid, \
the warranty don't cover the cost of \
cleaning up me kitchen. I need yer help, matey! \
"""
style = """American English \
in a calm and respectful tone. 
"""

# %%
prompt = f"""Translate the text \
that is delimited by triple backticks into a \
style that is {style} \
text: ```{customer_email}```
"""
print(prompt)
# Out:
# Translate the text that is delimited by triple backticks into a style that is American English in a calm and respectful tone.
#  text: ```
# Arrr, I be fuming that me blender lid flew off and splattered me kitchen walls with smoothie. I be needin' a new lid, the warranty don't cover the cost of cleaning up me kitchen. I need yer help, matey! ```

# %%
llm.invoke(prompt)
# Out:
# "```\nSailor, I am furious because my blender lid popped off and sprayed smoothies all over the kitchen walls. I need a new lid; unfortunately, the warranty doesn't cover the expense of cleaning up the kitchen. Could you assist me, friend? \n```"

# %%
for chunk in llm.stream("The first man on the moon was ..."):
    print(chunk, end="", flush=True)
# Out:
# The first person on the Moon was American astronaut Neil Armstrong, who landed there as part of the Apollo 11 mission in July 25, 1969. He took the famous step "one small step for man, one giant leap for mankind" on July 20, 1969.

# %%
template_string = """Translate the text that is delimited by \
    triple backticks into a style that is {style} 
    text: ```{text}```
    """

# %%
from langchain.prompts import ChatPromptTemplate
prompt_template = ChatPromptTemplate.from_template(template_string)

# %%
prompt_template.messages[0].prompt.input_variables
# Out:
# ['style', 'text']

# %%
cumstomer_style = """American English in a calm and respectful tone.
"""
customer_message = prompt_template.format_messages(
    text=customer_email, style=cumstomer_style
)

# %%
print(customer_message[0])
# Out:
# content="Translate the text that is delimited by     triple backticks into a style that is American English in a calm and respectful tone.\n \n    text: ```\nArrr, I be fuming that me blender lid flew off and splattered me kitchen walls with smoothie. I be needin' a new lid, the warranty don't cover the cost of cleaning up me kitchen. I need yer help, matey! ```\n    " additional_kwargs={} response_metadata={}

# %%
llm.invoke(customer_message)
# Out:
# '```\nI am quite frustrated because the lid on my blender flew off and ended up smearing the smoothies all over the walls of my kitchen. I require a new lid, as the warranty does not cover the expense of cleaning up my kitchen afterward. Can you please assist me, fellow pirate?\n```'

# %%
service_reply = """Hey there customer, \
    the warranty doesn't cover the cost of cleaning up your kitchen, \
    because it's your fault that you misused the blender \
    by forgetting to put the lid on before \
    starting it. Tough luck! see ya!
    """
service_style_pirate = """
    a plite tone that speaks like a pirate.
    """
service_message = prompt_template.format_messages(
    text=service_reply, style=service_style_pirate
)
print(service_message[0])
# Out:
# content="Translate the text that is delimited by     triple backticks into a style that is \n    a plite tone that speaks like a pirate.\n     \n    text: ```Hey there customer,     the warranty doesn't cover the cost of cleaning up your kitchen,     because it's your fault that you misused the blender     by forgetting to put the lid on before     starting it. Tough luck! see ya!\n    ```\n    " additional_kwargs={} response_metadata={}

# %%
llm.invoke(service_message)
# Out:
# "```Arrr matey! The waurantee don't pay for scrubbin' yar ol' kitchen coz ye was a culprit fer forgettin' ta put de lid on afore startin' dat blender. Me hearty, tough luck me hearties! Taere off now!\n```"

# %%
customer_review = """
    This leaf blower is pretty amazing. It has four settings: 
    candle blower, gentle breeze, windy city, and tornado. \ 
    It arrived in two days, just in time for my wife's \ 
    anniversary present. 
    I think my wife liked it so much she was speechless. \ 
    So far I've been the only one using it, and I've been \ 
    using it every other morning to clear the leaves on our lawn.
    It's slightly more expensive than the other leaf blowers \ 
    out there, but I think it's worth it for the extra features.
    """
review_template = """
    For the following text, extract the following information: 
    gift: Was the item purchased as a gift for someone else? Answer with "yes" or "no". 
    delivery_days: How many days did it take for the product to arrive?
    price_value: Extract any sentences about the value or price.
    
    Format the output as JSON with the following keys: 
    gift
    delivery_days
    price_value
    
    text: {text}
    """
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\00036777\AppData\Local\Temp\ipykernel_30296\2652627574.py:1: SyntaxWarning: invalid escape sequence '\ '
#   customer_review = """

# %%
from langchain.prompts import ChatPromptTemplate
prompt_template = ChatPromptTemplate.from_template(review_template)
print(prompt_template)
# Out:
# input_variables=['text'] input_types={} partial_variables={} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['text'], input_types={}, partial_variables={}, template='\n    For the following text, extract the following information: \n    gift: Was the item purchased as a gift for someone else? Answer with "yes" or "no". \n    delivery_days: How many days did it take for the product to arrive?\n    price_value: Extract any sentences about the value or price.\n    \n    Format the output as JSON with the following keys: \n    gift\n    delivery_days\n    price_value\n    \n    text: {text}\n    '), additional_kwargs={})]

# %%
message = prompt_template.format_messages(
    text=customer_review
)
res = llm.invoke(message)

# %%
print(type(res))
# Out:
# <class 'str'>

# %%
import langchain.output_parsers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 import langchain.output_parsers
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain\output_parsers\__init__.py:18
#       1 """**OutputParser** classes parse the output of an LLM call.
#       2
#       3 **Class hierarchy:**
#    (...)
#      13     Serializable, Generation, PromptValue
#      14 """  # noqa: E501
#      16 from typing import TYPE_CHECKING, Any
# ---> 18 from langchain_core.output_parsers import (
#      19     CommaSeparatedListOutputParser,
#      20     ListOutputParser,
#      21     MarkdownListOutputParser,
#      22     NumberedListOutputParser,
#      23     PydanticOutputParser,
#      24     XMLOutputParser,
#      25 )
#      26 from langchain_core.output_parsers.openai_tools import (
#      27     JsonOutputKeyToolsParser,
#      28     JsonOutputToolsParser,
#      29     PydanticToolsParser,
#      30 )
#      32 from langchain._api import create_importer
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\output_parsers\__init__.py:92, in __getattr__(attr_name)
#      90 def __getattr__(attr_name: str) -> object:
#      91     module_name = _dynamic_imports.get(attr_name)
# ---> 92     result = import_attr(attr_name, module_name, __spec__.parent)
#      93     globals()[attr_name] = result
#      94     return result
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\_import_utils.py:29, in import_attr(attr_name, module_name, package)
#      27 else:
#      28     try:
# ---> 29         module = import_module(f".{module_name}", package=package)
#      30     except ModuleNotFoundError:
#      31         msg = f"module '{package!r}.{module_name!r}' not found"
#
# File d:\anaconda3\envs\bo\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\output_parsers\pydantic.py:11
#       8 from typing_extensions import override
#      10 from langchain_core.exceptions import OutputParserException
# ---> 11 from langchain_core.output_parsers import JsonOutputParser
#      12 from langchain_core.outputs import Generation
#      13 from langchain_core.utils.pydantic import (
#      14     IS_PYDANTIC_V2,
#      15     PydanticBaseModel,
#      16     TBaseModel,
#      17 )
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\output_parsers\__init__.py:92, in __getattr__(attr_name)
#      90 def __getattr__(attr_name: str) -> object:
#      91     module_name = _dynamic_imports.get(attr_name)
# ---> 92     result = import_attr(attr_name, module_name, __spec__.parent)
#      93     globals()[attr_name] = result
#      94     return result
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\_import_utils.py:29, in import_attr(attr_name, module_name, package)
#      27 else:
#      28     try:
# ---> 29         module = import_module(f".{module_name}", package=package)
#      30     except ModuleNotFoundError:
#      31         msg = f"module '{package!r}.{module_name!r}' not found"
#
# File d:\anaconda3\envs\bo\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\output_parsers\json.py:22
#      16 from langchain_core.outputs import Generation
#      17 from langchain_core.utils.json import (
#      18     parse_and_check_json_markdown,
#      19     parse_json_markdown,
#      20     parse_partial_json,
#      21 )
# ---> 22 from langchain_core.utils.pydantic import IS_PYDANTIC_V1
#      24 if IS_PYDANTIC_V1:
#      25     PydanticBaseModel = pydantic.BaseModel
#
# ImportError: cannot import name 'IS_PYDANTIC_V1' from 'langchain_core.utils.pydantic' (d:\anaconda3\envs\bo\Lib\site-packages\langchain_core\utils\pydantic.py)
