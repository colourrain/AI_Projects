# %%
import os

# 从环境变量中获取您的API KEY，配置方法见：https://www.volcengine.com/docs/82379/1399008
api_key = os.getenv('ARK_API_KEY')
print(api_key)
# Out:
# a5b9cf1e-718a-49b4-b826-a8821ec3c040

# %%
import os
from openai import OpenAI
client = OpenAI(
    base_url="https://ark.cn-beijing.volces.com/api/v3",
    api_key=api_key,
)

response = client.responses.create(
    model="doubao-seed-1-6-250615",
    input=[
        {
            "role": "user",
            "content": [

                {
                    "type": "input_image",
                    "image_url": "https://ark-project.tos-cn-beijing.volces.com/doc_image/ark_demo_img_1.png"
                },
                {
                    "type": "input_text",
                    "text": "你看见了什么？"
                },
            ],
        }
    ]
)

print(response)
# Out:
# Response(id='resp_02176882351182179c9f8f60c75009b5dc4fac7a685c51d6e0ece', created_at=1768823512.0, error=None, incomplete_details=None, instructions=None, metadata=None, model='doubao-seed-1-6-250615', object='response', output=[ResponseReasoningItem(id='rs_02176882351284000000000000000000000ffffac1516a8d5a8fa', summary=[Summary(text='\n用户现在问的是“你看见了什么？”，需要我根据提供的表格内容进行描述。首先，我需要仔细看表格的结构和内容。表格的标题是“输入输出”，说明是关于模型系列的输入和输出类型的支持情况。\n\n首先，表格的列有“模型系列”，然后是“输入”部分，包括“文本”、“图像”、“音频”；“输出”部分也包括“文本”、“图像”、“音频”。行是不同的模型系列，有三个：Doubao-1.5-pro、Doubao-1.5-lite、Doubao-1.5-vision。\n\n接下来看每个模型的输入输出支持情况。对于输入中的“文本”，三个模型都是支持的（√）。输入中的“图像”：Doubao-1.5-pro和Doubao-1.5-lite不支持（×），而Doubao-1.5-vision支持（√）。输入中的“音频”：三个模型都不支持（×）。\n\n输出方面，“文本”：三个模型都支持（√）。“图像”：三个模型都不支持（×）。“音频”：三个模型都不支持（×）。\n\n另外，表格上方有说明：“×：不支持。√：支持。”，并且提示用户可以根据业务的输出输出信息类型筛选模型。\n\n所以需要把这些信息整理出来，说明表格的主题、结构（模型系列、输入输出类型），然后分模型说明各自的输入输出支持情况，总结共同点和不同点。比如共同点是都支持文本输入和文本输出，不支持音频输入和音频输出、图像输出；不同点是Doubao-1.5-vision额外支持图像输入，而前两个模型不支持图像输入。\n\n需要注意用词准确，分点清晰，让用户清楚看到表格的主要内容和各模型的特点。', type='summary_text')], type='reasoning', content=None, encrypted_content=None, status='completed'), ResponseOutputMessage(id='msg_02176882352096200000000000000000000ffffac1516a8d82a05', content=[ResponseOutputText(annotations=None, text='我看到一张关于模型系列输入输出信息类型支持情况的表格，具体内容如下：\n\n\n### **表格主题**  \n用于根据业务的输入输出信息类型快速筛选模型，标注“√”表示支持，“×”表示不支持。\n\n\n### **表格结构**  \n- **行**：3个模型系列，分别为 `Doubao-1.5-pro`、`Doubao-1.5-lite`、`Doubao-1.5-vision`。  \n- **列**：分为“模型系列”“输入”“输出”三大类，其中“输入”和“输出”又各细分3种类型：**文本、图像、音频**。  \n\n\n### **各模型输入输出支持情况**  \n#### 1. **Doubao-1.5-pro**  \n- **输入**：仅支持文本（√），不支持图像（×）、音频（×）。  \n- **输出**：仅支持文本（√），不支持图像（×）、音频（×）。  \n\n\n#### 2. **Doubao-1.5-lite**  \n- **输入**：仅支持文本（√），不支持图像（×）、音频（×）。  \n- **输出**：仅支持文本（√），不支持图像（×）、音频（×）。  \n\n\n#### 3. **Doubao-1.5-vision**  \n- **输入**：支持文本（√）和图像（√），不支持音频（×）。  \n- **输出**：仅支持文本（√），不支持图像（×）、音频（×）。  \n\n\n### **核心结论**  \n- **共同点**：3个模型均支持“文本输入”和“文本输出”，均不支持“音频输入”“音频输出”“图像输出”。  \n- **差异点**：仅 `Doubao-1.5-vision` 额外支持“图像输入”，而 `Doubao-1.5-pro` 和 `Doubao-1.5-lite` 不支持图像输入。', type='output_text', logprobs=None)], role='assistant', status='completed', type='message')], parallel_tool_calls=None, temperature=None, tool_choice=None, tools=None, top_p=None, background=None, conversation=None, max_output_tokens=32768, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=None, safety_identifier=None, service_tier='default', status='completed', text=None, top_logprobs=None, truncation=None, usage=ResponseUsage(input_tokens=1087, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=866, output_tokens_details=OutputTokensDetails(reasoning_tokens=417), total_tokens=1953), user=None, caching={'type': 'disabled'}, store=True, expire_at=1769082711)
