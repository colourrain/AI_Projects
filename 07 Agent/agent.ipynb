# %%
import os
from langchain_openai import ChatOpenAI

#获取api_key
api_key = os.getenv('ARK_API_KEY')
print(api_key)
# Out:
# a5b9cf1e-718a-49b4-b826-a8821ec3c040

# %%
model = ChatOpenAI(
    openai_api_base="https://ark.cn-beijing.volces.com/api/v3",
    openai_api_key=api_key,	# app_key
    model_name="doubao-seed-1-6-flash-250828",	# 您想使用的特定模型的名称或标识符。
    max_tokens=1000, #限制响应中的令牌总数，有效控制输出长度。
    temperature= 0.7,  #控制模型输出的随机性。值越高，响应越具创造性；值越低，响应越确定性。
    timeout=30, #模型的响应时间s
)
response = model.invoke("夏天适合吃什么水果")

# %%
print(response.content)
# Out:
# 夏天天气炎热，人体易缺水、燥热，适合选择水分充足、清热解暑、富含维生素和矿物质的水果。以下是一些适合夏天吃的水果推荐，附特点及食用建议：
#
#
# ### **1. 西瓜——补水降温“神器”**
# **特点**：含水量超90%，富含葡萄糖、维生素C、番茄红素，能快速补水、缓解暑热。
# **优势**：冰镇后食用更解暑，但含糖量较高（约5%-12%），建议每次200-300克，避免过量。
# **注意**：脾胃虚寒者（易腹泻、手脚凉）少吃，避免空腹吃。
#
#
# ### **2. 桃子（水蜜桃/油桃）——清甜多汁**
# **特点**：水分足、膳食纤维丰富，含钾量高（补钾防中暑），维生素C和类胡萝卜素含量高。
# **优势**：酸甜适口，能生津止渴，促进消化。选软熟的桃子更甜，未熟的可催熟后吃。
# **注意**：桃毛需洗净，肠胃敏感者少量尝试。
#
#
# ### **3. 葡萄——补糖+抗氧化**
# **特点**：水分多、富含葡萄糖、花青素和维生素K，酸甜开胃，冰镇后口感更佳。
# **推荐品种**：巨峰（甜）、夏黑（无籽）、阳光玫瑰（脆甜）。
# **优势**：补能量快，适合运动后吃；花青素抗氧化，保护血管。
# **注意**：葡萄皮和籽含营养，但需彻底洗净，避免农药残留。
#
#
# ### **4. 梨——润肺生津“润燥王”**
# **特点**：含水量高（约85%），性凉，含苹果酸、维生素B族，能缓解燥热、润肺止咳。
# **推荐**：香梨（清甜）、贡梨（多汁）、皇冠梨（脆甜）。
# **优势**：生吃润喉，煮梨水（加冰糖、川贝）更适合咳嗽咽干者。
# **
